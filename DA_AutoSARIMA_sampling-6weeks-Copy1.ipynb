# %%
import pandas as pd
import math as m
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sklearn.model_selection import train_test_split

from time import time
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import acf
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
import pmdarima as pm

"""To display up to 50 columns of dataset"""
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 8)

"""To display all outputs of each cell"""
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"


np.random.seed(100)

"""To get a timing of each function decorated"""
def timing(f):
    """
    Decorator for timing functions
    Usage:
    @timing
    def function(&):
        pass
    """
    
    def wrapper(*args, **kwargs):
        start = time()
        result = f(*args, **kwargs)
        end = time()
        print('function:%r took: %2.2f sec' % (f.__name__, end - start))
        return result
    return wrapper

class Trainer():
    def __init__(self, input_directory, df_): #input_directory = path to the folder containing df. 
        self.input_directory = input_directory
        self.df = df_
                
    @timing
    def read(self):
        """Read raw data"""
        self.df = pd.read_csv(self.input_directory + self.df)
    
    @timing
    def auto_arima(self, nb_store):
        #Date as index
        self.df = self.df[self.df["Open"] == 1]
        self.df = pd.DataFrame(self.df, columns=['Date','Store','Sales'])
        self.df.sort_values(['Store', 'Date'], ascending=[True, True], inplace=True)
        #Re_indexation 
        self.df = self.df.reset_index(drop='True')
        
        """put the date as index"""
        self.df["Date"] = pd.to_datetime(self.df["Date"].astype(str), format = '%Y/%m/%d')
        self.df = self.df.set_index("Date")
        
        self.subset = self.df[(self.df["Store"]==(nb_store))]
        self.subset = self.subset.drop(["Store"], axis = 1)

        # Split train and test set  
        self.train = self.subset.loc[:'2015-06-13', :]
        self.test = self.subset.loc['2015-06-14':, :]

        # Build Model
        self.model = pm.auto_arima(self.subset.Sales, start_p=1, start_q=1,
                          test='adf',       # use adftest to find optimal 'd'
                          max_p=3, max_q=3, # maximum p and q
                          m=12,              # frequency of series
                          d=0,           # let model determine 'd'
                          seasonal=True,   # No Seasonality
                          start_P=1, max_P=2,
                          D=1, 
                          trace=True,
                          error_action='ignore',  
                          suppress_warnings=True, 
                          stepwise=True)
        
        # Forecast
        self.n_periods = len(self.test)
        self.fc, self.confint = self.model.predict(n_periods=self.n_periods, return_conf_int=True)

        self.fc_series = pd.DataFrame(self.fc)
        self.fc_series.columns = ['predicted_SARIMA']
        self.fc_series = self.fc_series.reset_index(drop=True)
        self.fc_series = self.fc_series.set_index(self.test.index)
        self.test.columns = ['Sales']

        # Validate
        self.errors = abs(self.fc_series['predicted_SARIMA'] - self.test['Sales'])
        self.mae = round(np.mean(self.errors), 2)
        self.rmse = round(m.sqrt((1/len(self.test))*sum(self.errors**2)), 2)

        self.result = pd.merge(self.test, self.fc_series ,how = 'left',left_index = True, right_index = True)
        self.result["error_SARIMA"] = abs(self.result['predicted_SARIMA'] - self.result['Sales'])

        return self.result

# %%
project = Trainer("/Users/rfdanti/Documents/UoM/2_data_analytics/coursework/CODE/", "full_trainset_v2.csv")
project.read()
result_403 = project.auto_arima(403)
result_403 = result_403.reset_index(drop=False)
result_403.head()
# Out:
# function:'read' took: 2.13 sec
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=13490.636, BIC=13518.491, Fit time=3.543 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=13732.638, BIC=13741.923, Fit time=0.054 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=13611.178, BIC=13629.748, Fit time=0.374 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=13556.956, BIC=13575.526, Fit time=1.297 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=13519.469, BIC=13542.681, Fit time=2.516 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 1, 1, 12); AIC=13490.421, BIC=13522.918, Fit time=8.464 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 1, 0, 12); AIC=13551.976, BIC=13579.831, Fit time=4.419 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 1, 2, 12); AIC=13516.953, BIC=13554.093, Fit time=10.479 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 0, 12); AIC=13575.733, BIC=13598.945, Fit time=1.579 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(2, 1, 1, 12); AIC=13514.795, BIC=13542.650, Fit time=5.718 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 1, 1, 12); AIC=13490.158, BIC=13527.298, Fit time=10.260 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 1, 12); AIC=13459.816, BIC=13492.314, Fit time=9.470 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 1, 1, 12); AIC=13488.166, BIC=13529.948, Fit time=13.299 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=13471.507, BIC=13499.362, Fit time=3.444 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 0, 12); AIC=13523.907, BIC=13551.761, Fit time=4.466 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 2, 12); AIC=13493.430, BIC=13530.570, Fit time=10.708 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=13548.674, BIC=13571.887, Fit time=1.515 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 1, 1, 12); AIC=13512.692, BIC=13540.547, Fit time=8.024 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 1, 1, 12); AIC=13458.417, BIC=13495.557, Fit time=11.336 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=13468.816, BIC=13501.313, Fit time=4.025 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 1, 0, 12); AIC=13524.417, BIC=13556.915, Fit time=4.832 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 1, 2, 12); AIC=13491.596, BIC=13533.378, Fit time=12.310 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=13559.154, BIC=13587.009, Fit time=0.645 seconds
# Total fit time: 132.783 seconds
# function:'auto_arima' took: 133.52 sec
#         Date  Sales  predicted_SARIMA  error_SARIMA
# 0 2015-06-15  12441       6128.627049   6312.372951
# 1 2015-06-16   9790       8065.863294   1724.136706
# 2 2015-06-17   9176       7331.771196   1844.228804
# 3 2015-06-18   8040       7071.658547    968.341453
# 4 2015-06-19   7619       7175.703665    443.296335

# %%
project = Trainer("/Users/rfdanti/Documents/UoM/2_data_analytics/coursework/CODE/", "full_trainset_v2.csv")
project.read()
result_351 = project.auto_arima(351)
result_351 = result_351.reset_index(drop=False)
result_351.head()
# Out:
# function:'read' took: 2.25 sec
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=13350.027, BIC=13373.317, Fit time=0.312 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=13667.225, BIC=13676.541, Fit time=0.020 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=13354.029, BIC=13372.661, Fit time=0.678 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=13417.566, BIC=13436.198, Fit time=0.584 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=13338.380, BIC=13366.328, Fit time=2.794 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=13336.488, BIC=13359.778, Fit time=1.326 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=13333.431, BIC=13366.037, Fit time=7.837 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=13393.261, BIC=13421.209, Fit time=3.913 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=13287.346, BIC=13324.610, Fit time=6.322 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=13301.533, BIC=13334.139, Fit time=5.511 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=13417.262, BIC=13459.184, Fit time=8.965 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=13299.833, BIC=13327.781, Fit time=4.243 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=13286.152, BIC=13332.732, Fit time=8.145 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=13285.509, BIC=13327.431, Fit time=3.617 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 0, 12); AIC=13305.132, BIC=13342.397, Fit time=3.393 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=13283.572, BIC=13330.152, Fit time=7.345 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=13346.288, BIC=13383.552, Fit time=1.027 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=13455.196, BIC=13497.118, Fit time=5.660 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(1, 0, 2, 12); AIC=13275.041, BIC=13326.279, Fit time=7.422 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=13276.918, BIC=13323.498, Fit time=6.375 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=13290.796, BIC=13346.693, Fit time=8.022 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=13291.013, BIC=13332.935, Fit time=3.896 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(0, 0, 2, 12); AIC=13304.370, BIC=13350.950, Fit time=6.254 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=13272.084, BIC=13327.980, Fit time=9.807 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(2, 0, 1, 12); AIC=13275.127, BIC=13326.365, Fit time=8.512 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=13276.329, BIC=13322.909, Fit time=2.962 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(2, 0, 2, 12); AIC=13285.580, BIC=13336.819, Fit time=7.602 seconds
# Fit ARIMA: order=(4, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=13286.172, BIC=13337.411, Fit time=8.017 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=13287.017, BIC=13333.597, Fit time=8.622 seconds
# Total fit time: 149.223 seconds
# function:'auto_arima' took: 149.89 sec
#         Date  Sales  predicted_SARIMA  error_SARIMA
# 0 2015-06-15   9850       6715.093758   3134.906242
# 1 2015-06-16   7449       6348.952442   1100.047558
# 2 2015-06-17   6829       5553.533569   1275.466431
# 3 2015-06-18   6628       5498.469978   1129.530022
# 4 2015-06-19   6716       5489.072939   1226.927061

# %%
result_351.to_csv("SARIMA_store351_6weeks.csv", index=False)

# %%
project = Trainer("/Users/rfdanti/Documents/UoM/2_data_analytics/coursework/CODE/", "full_trainset_v2.csv")
project.read()
result_279 = project.auto_arima(279)
result_279 = result_279.reset_index(drop=False)
result_279.head()
# Out:
# function:'read' took: 2.66 sec
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=14260.924, BIC=14284.208, Fit time=0.344 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=14635.887, BIC=14645.201, Fit time=0.021 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=14245.976, BIC=14264.603, Fit time=0.574 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=14307.935, BIC=14326.562, Fit time=0.556 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=14343.359, BIC=14357.329, Fit time=0.154 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 0, 12); AIC=14244.064, BIC=14267.348, Fit time=3.232 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=14215.690, BIC=14243.631, Fit time=3.489 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=14435.978, BIC=14459.262, Fit time=3.095 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 0, 1, 12); AIC=14217.800, BIC=14250.397, Fit time=4.177 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=14217.997, BIC=14250.594, Fit time=5.102 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 1, 12); AIC=14212.629, BIC=14249.883, Fit time=3.305 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=14203.456, BIC=14236.053, Fit time=2.194 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 0, 0, 12); AIC=14226.881, BIC=14254.822, Fit time=3.359 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 0, 2, 12); AIC=14214.726, BIC=14251.980, Fit time=3.214 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=14346.826, BIC=14370.110, Fit time=0.264 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 0, 2, 12); AIC=14208.842, BIC=14250.752, Fit time=5.816 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=14239.907, BIC=14267.848, Fit time=1.704 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=14205.724, BIC=14242.978, Fit time=4.342 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=14246.608, BIC=14274.549, Fit time=1.344 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=14218.482, BIC=14255.736, Fit time=2.270 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 1, 12); AIC=14242.889, BIC=14266.173, Fit time=0.712 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 0, 1, 12); AIC=14207.706, BIC=14249.616, Fit time=2.665 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=14262.541, BIC=14290.482, Fit time=0.543 seconds
# Total fit time: 52.500 seconds
# function:'auto_arima' took: 53.17 sec
#         Date  Sales  predicted_SARIMA  error_SARIMA
# 0 2015-06-15  19655      10799.676032   8855.323968
# 1 2015-06-16  11692       9620.939810   2071.060190
# 2 2015-06-17  12551       8422.759637   4128.240363
# 3 2015-06-18  10696       8126.531380   2569.468620
# 4 2015-06-19  10873       8877.243697   1995.756303

# %%
result_279.to_csv("SARIMA_store279_6weeks.csv", index=False)

# %%
project = Trainer("/Users/rfdanti/Documents/UoM/2_data_analytics/coursework/CODE/", "full_trainset_v2.csv")
project.read()
result_733 = project.auto_arima(733)
result_733 = result_733.reset_index(drop=False)
result_733.head()
# Out:
# function:'read' took: 2.68 sec
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=16483.942, BIC=16508.182, Fit time=0.534 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=16837.285, BIC=16846.981, Fit time=0.028 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=16503.880, BIC=16523.272, Fit time=0.829 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=16598.138, BIC=16617.530, Fit time=0.939 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=16755.885, BIC=16784.973, Fit time=2.722 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=16481.977, BIC=16501.369, Fit time=0.200 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=16608.055, BIC=16622.599, Fit time=0.324 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=16479.084, BIC=16503.324, Fit time=0.296 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=16480.343, BIC=16499.735, Fit time=0.432 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 0, 0, 12); AIC=16470.212, BIC=16499.300, Fit time=0.678 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=16464.117, BIC=16502.901, Fit time=1.140 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(1, 0, 0, 12); AIC=17334.204, BIC=17377.836, Fit time=3.164 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=16327.545, BIC=16371.177, Fit time=3.994 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=16882.374, BIC=16935.702, Fit time=9.410 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=16455.165, BIC=16493.949, Fit time=1.897 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=16318.128, BIC=16366.608, Fit time=3.883 seconds
# Fit ARIMA: order=(4, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=16443.680, BIC=16487.312, Fit time=3.041 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=16471.179, BIC=16509.963, Fit time=2.270 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(1, 0, 1, 12); AIC=16516.435, BIC=16569.763, Fit time=4.720 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=16352.928, BIC=16396.560, Fit time=1.717 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=16321.898, BIC=16375.226, Fit time=9.372 seconds
# Fit ARIMA: order=(4, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=16482.787, BIC=16540.963, Fit time=11.396 seconds
# Fit ARIMA: order=(5, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=16352.845, BIC=16406.173, Fit time=3.926 seconds
# Total fit time: 66.938 seconds
# function:'auto_arima' took: 67.59 sec
#         Date  Sales  predicted_SARIMA  error_SARIMA
# 0 2015-06-14  16452      14656.415472   1795.584528
# 1 2015-06-15  16710      15189.754797   1520.245203
# 2 2015-06-16  16007      15485.621578    521.378422
# 3 2015-06-17  15036      14265.267545    770.732455
# 4 2015-06-18  15269      14428.190578    840.809422

# %%
result_733.to_csv("SARIMA_store733_6weeks.csv", index=False)

# %%
trainset = pd.read_csv("full_trainset_v2.csv")

#Date as index
df = trainset[trainset["Open"] == 1]
df = pd.DataFrame(df, columns=['Date','Store','Sales'])
df.sort_values(['Store', 'Date'], ascending=[True, True], inplace=True)
df = df.reset_index(drop=True)
df = df.set_index('Date')

# %%
import pmdarima as pm
dt = time()
mae_list = []
rmse_list = []
for i in range(len(df["Store"].unique())):
    try:
        # Filter by Store
        subset = df[(df["Store"]==(i+1))]
        subset = subset.drop(["Store"], axis = 1)

        # Split train and test set  
        train = subset.loc[:'2015-06-13', :]
        test = subset.loc['2015-06-14':, :]

        # Build Model
        model = pm.auto_arima(subset.Sales, start_p=2, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=2, # maximum p and q
                      m=12,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=True,   # Seasonality
                      start_P=1, max_P=2, Q=1,
                      D=1, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
        # Forecast
        n_periods = len(test)
        fc, confint = model.predict(n_periods=n_periods, return_conf_int=True)
        
        fc_series = pd.DataFrame(fc)
        fc_series.columns = ['Sales']
        fc_series = fc_series.reset_index(drop=True)
        fc_series = fc_series.set_index(test.index)
        test.columns = ['Sales']

        # Validate
        errors = abs(fc_series['Sales'] - test['Sales'])
        mae = round(np.mean(errors), 2)
        rmse = round(m.sqrt((1/len(test))*sum(errors**2)), 2)

        mae_list.append(mae)
        rmse_list.append(rmse)
    
    except:
        mae_list.append(np.nan)
        rmse_list.append(np.nan)
        pass

duration = time() - dt
print(duration)
print(rmse_list)
# Out:
# /Users/rfdanti/anaconda3/lib/python3.7/site-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /Users/rfdanti/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=12356.254, BIC=12384.125, Fit time=4.021 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=13049.551, BIC=13058.842, Fit time=0.056 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=12509.540, BIC=12528.120, Fit time=1.234 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=12552.645, BIC=12571.226, Fit time=2.472 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=12363.684, BIC=12386.909, Fit time=2.867 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 1, 12); AIC=12349.369, BIC=12381.885, Fit time=13.848 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 0, 12); AIC=12454.375, BIC=12482.246, Fit time=6.350 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 2, 12); AIC=12363.857, BIC=12401.017, Fit time=17.232 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=12499.872, BIC=12523.097, Fit time=1.594 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 1, 1, 12); AIC=12354.305, BIC=12382.176, Fit time=10.692 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 1, 1, 12); AIC=12350.742, BIC=12387.903, Fit time=13.880 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 1, 1, 12); AIC=12343.502, BIC=12380.662, Fit time=15.181 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=13291.970, BIC=13319.864, Fit time=3.730 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=13527.397, BIC=13536.695, Fit time=0.060 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=13390.994, BIC=13409.590, Fit time=1.177 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=13369.717, BIC=13388.313, Fit time=1.232 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=13346.540, BIC=13369.785, Fit time=0.532 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 1, 12); AIC=13294.068, BIC=13326.611, Fit time=12.567 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=13380.572, BIC=13403.817, Fit time=0.679 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 2, 12); AIC=13302.553, BIC=13335.096, Fit time=13.451 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=13450.310, BIC=13468.906, Fit time=0.186 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 2, 12); AIC=13306.977, BIC=13344.168, Fit time=14.483 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=13308.055, BIC=13331.300, Fit time=3.147 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=13262.704, BIC=13295.247, Fit time=5.614 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=13273.650, BIC=13310.842, Fit time=5.865 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=13301.981, BIC=13329.875, Fit time=1.969 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 1, 1, 12); AIC=13254.063, BIC=13291.255, Fit time=15.093 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 1, 0, 12); AIC=13311.553, BIC=13344.096, Fit time=6.765 seconds

# %%
rmse_list = pd.DataFrame(rmse_list, columns=["RMSE"])
mae_list = pd.DataFrame(mae_list, columns=["MAE"])

store = list(range(1,1116))
store_series = pd.DataFrame(store, columns=["Store"])
result = pd.merge(store_series, rmse_list, how = 'left',left_index = True, right_index = True)
result = pd.merge(result, mae_list, how = 'left',left_index = True, right_index = True)
result.head()

# %%
result.RMSE.mean()

# %%
result.RMSE.median()

# %%
result.to_csv("arima_result_6weeks.csv", index=False)
